# %% [markdown]
# # Importing Libraries  and Data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Turning a project folder path into a string

path = r'/Users/mart/Documents/08-2022 IBRD & IDA Net Flows & Commitments'

# %%
# Importing database

df = pd.read_csv(os.path.join(path,'02 Data','Original Data', 'IBRD_and_IDA_Net_Flows_Commitments.csv'), index_col = False)

# %% [markdown]
# # Data Consistency Checks

# %%
df.shape
# Out:
# (2650, 14)

# %%
df.head()
# Out:
#   Financier  Fiscal Year                       Region   Country  \
# 0       IDA         2010                       AFRICA    Africa
# 1       IDA         2010  EASTERN AND SOUTHERN AFRICA    Angola
# 2      IBRD         2010  EASTERN AND SOUTHERN AFRICA  Botswana
# 3       IDA         2010  EASTERN AND SOUTHERN AFRICA  Botswana
# 4       IDA         2010  EASTERN AND SOUTHERN AFRICA   Burundi
#
#    Gross Disbursement (US$)  Repayments (US$)  Net Disbursement (US$)  \
# 0                8436193.56              0.00              8436193.56
# 1               19767855.19        5763290.04             14004565.15
# 2                2377000.89              0.00              2377000.89
# 3                      0.00         477444.22              -477444.22
# 4               88240174.47           6569.85             88233604.62
#
#    Interest (US$)  Fees (US$)  IBRD Commitments (US$)  \
# 0        74414.55         0.0                     0.0
# ...

# %%
df.tail()
# Out:
#      Financier  Fiscal Year                      Region  \
# 2645       IDA         2023  WESTERN AND CENTRAL AFRICA
# 2646       IDA         2023  WESTERN AND CENTRAL AFRICA
# 2647       IDA         2023  WESTERN AND CENTRAL AFRICA
# 2648       IDA         2023  WESTERN AND CENTRAL AFRICA
# 2649       IDA         2023  WESTERN AND CENTRAL AFRICA
#
#                          Country  Gross Disbursement (US$)  Repayments (US$)  \
# 2645                     Nigeria               70069600.94        5908802.86
# 2646                     Senegal               14887103.21        7589282.84
# 2647                Sierra Leone                7810745.82         718728.59
# 2648                        Togo                8061364.58              0.00
# 2649  Western and Central Africa               15376910.04        2365590.38
#
#       Net Disbursement (US$)  Interest (US$)  Fees (US$)  \
# 2645             64160798.08      8397764.36        0.00
# ...

# %%
# check the info and data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2650 entries, 0 to 2649
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Financier                               2650 non-null   object
#  1   Fiscal Year                             2650 non-null   int64
#  2   Region                                  2650 non-null   object
#  3   Country                                 2650 non-null   object
#  4   Gross Disbursement (US$)                2650 non-null   float64
#  5   Repayments (US$)                        2650 non-null   float64
#  6   Net Disbursement (US$)                  2650 non-null   float64
#  7   Interest (US$)                          2650 non-null   float64
#  8   Fees (US$)                              2650 non-null   float64
#  9   IBRD Commitments (US$)                  2650 non-null   float64
# ...

# %%
df['Fiscal Year'].describe()
# Out:
# count    2650.000000
# mean     2016.420000
# std         3.996674
# min      2010.000000
# 25%      2013.000000
# 50%      2016.000000
# 75%      2020.000000
# max      2023.000000
# Name: Fiscal Year, dtype: float64

# %%
df.describe()
# Out:
#        Fiscal Year  Gross Disbursement (US$)  Repayments (US$)  \
# count  2650.000000              2.650000e+03      2.650000e+03
# mean   2016.420000              1.773647e+08      7.516579e+07
# std       3.996674              3.971425e+08      2.272914e+08
# min    2010.000000             -3.384851e+06     -4.375000e+01
# 25%    2013.000000              5.931438e+05      6.062651e+05
# 50%    2016.000000              2.386822e+07      5.046114e+06
# 75%    2020.000000              1.348164e+08      4.030564e+07
# max    2023.000000              4.626034e+09      4.169492e+09
#
#        Net Disbursement (US$)  Interest (US$)    Fees (US$)  \
# count            2.650000e+03    2.650000e+03  2.650000e+03
# mean             1.021989e+08    2.155616e+07  4.844695e+05
# std              3.071452e+08    5.602837e+07  1.983309e+06
# min             -1.704373e+09    0.000000e+00  0.000000e+00
# 25%             -9.588655e+05    2.423626e+05  0.000000e+00
# ...

# %%
# check for mixed types

for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)

# %%
# find missing values

df.isnull().sum()
# Out:
# Financier                                 0
# Fiscal Year                               0
# Region                                    0
# Country                                   0
# Gross Disbursement (US$)                  0
# Repayments (US$)                          0
# Net Disbursement (US$)                    0
# Interest (US$)                            0
# Fees (US$)                                0
# IBRD Commitments (US$)                    0
# IDA Grant Commitments (US$)               0
# IDA Non-Concessional Commitments (US$)    0
# IDA Concessional Commitments (US$)        0
# IDA Other Commitments (US$)               0
# dtype: int64

# %%
# count a percentage for missing values

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Financier - 0%
# Fiscal Year - 0%
# Region - 0%
# Country - 0%
# Gross Disbursement (US$) - 0%
# Repayments (US$) - 0%
# Net Disbursement (US$) - 0%
# Interest (US$) - 0%
# Fees (US$) - 0%
# IBRD Commitments (US$) - 0%
# IDA Grant Commitments (US$) - 0%
# IDA Non-Concessional Commitments (US$) - 0%
# IDA Concessional Commitments (US$) - 0%
# IDA Other Commitments (US$) - 0%

# %%
#look for duplicates
df_dups = df[df.duplicated()]
df_dups
# Out:
# Empty DataFrame
# Columns: [Financier, Fiscal Year, Region, Country, Gross Disbursement (US$), Repayments (US$), Net Disbursement (US$), Interest (US$), Fees (US$), IBRD Commitments (US$), IDA Grant Commitments (US$), IDA Non-Concessional Commitments (US$), IDA Concessional Commitments (US$), IDA Other Commitments (US$)]
# Index: []

# %%
df.shape
# Out:
# (2650, 14)

# %%
# checking 2023 Year

df[df['Fiscal Year']==2023]
# Out:
#      Financier  Fiscal Year                      Region  \
# 2497      IBRD         2023       EAST ASIA AND PACIFIC
# 2498      IBRD         2023       EAST ASIA AND PACIFIC
# 2499      IBRD         2023       EAST ASIA AND PACIFIC
# 2500      IBRD         2023       EAST ASIA AND PACIFIC
# 2501      IBRD         2023       EAST ASIA AND PACIFIC
# ...        ...          ...                         ...
# 2645       IDA         2023  WESTERN AND CENTRAL AFRICA
# 2646       IDA         2023  WESTERN AND CENTRAL AFRICA
# 2647       IDA         2023  WESTERN AND CENTRAL AFRICA
# 2648       IDA         2023  WESTERN AND CENTRAL AFRICA
# 2649       IDA         2023  WESTERN AND CENTRAL AFRICA
#
#                          Country  Gross Disbursement (US$)  Repayments (US$)  \
# 2497                       China              5.712253e+07       31987393.76
# 2498                        Fiji              5.090013e+07         218003.93
# ...

# %%
df[df['IBRD Commitments (US$)']==0]
# Out:
#      Financier  Fiscal Year                       Region  \
# 0          IDA         2010                       AFRICA
# 1          IDA         2010  EASTERN AND SOUTHERN AFRICA
# 3          IDA         2010  EASTERN AND SOUTHERN AFRICA
# 4          IDA         2010  EASTERN AND SOUTHERN AFRICA
# 5          IDA         2010  EASTERN AND SOUTHERN AFRICA
# ...        ...          ...                          ...
# 2645       IDA         2023   WESTERN AND CENTRAL AFRICA
# 2646       IDA         2023   WESTERN AND CENTRAL AFRICA
# 2647       IDA         2023   WESTERN AND CENTRAL AFRICA
# 2648       IDA         2023   WESTERN AND CENTRAL AFRICA
# 2649       IDA         2023   WESTERN AND CENTRAL AFRICA
#
#                          Country  Gross Disbursement (US$)  Repayments (US$)  \
# 0                         Africa                8436193.56              0.00
# 1                         Angola               19767855.19        5763290.04
# ...

# %%
 (df == 0).sum(axis=0)
# Out:
# Financier                                    0
# Fiscal Year                                  0
# Region                                       0
# Country                                      0
# Gross Disbursement (US$)                   568
# Repayments (US$)                           367
# Net Disbursement (US$)                      58
# Interest (US$)                             180
# Fees (US$)                                1901
# IBRD Commitments (US$)                       0
# IDA Grant Commitments (US$)               2159
# IDA Non-Concessional Commitments (US$)    2597
# IDA Concessional Commitments (US$)        2000
# IDA Other Commitments (US$)               2609
# dtype: int64

# %%
df[df['Interest (US$)'] == 0].shape[0]
# Out:
# 180

# %%
# checking for some outliers

df.boxplot(column=['Fees (US$)'])
# Out:
# <AxesSubplot:>

# %%
# ordering Data to see outliers

df.sort_values(by=['Fees (US$)'], inplace=False, ascending=False)
# Out:
#      Financier  Fiscal Year                       Region  \
# 730       IBRD         2013  LATIN AMERICA AND CARIBBEAN
# 323       IBRD         2011  LATIN AMERICA AND CARIBBEAN
# 1196       IDA         2016   WESTERN AND CENTRAL AFRICA
# 1840      IBRD         2019      EUROPE AND CENTRAL ASIA
# 2175      IBRD         2021      EUROPE AND CENTRAL ASIA
# ...        ...          ...                          ...
# 995       IBRD         2015   WESTERN AND CENTRAL AFRICA
# 994        IDA         2015   WESTERN AND CENTRAL AFRICA
# 993        IDA         2015   WESTERN AND CENTRAL AFRICA
# 992        IDA         2015   WESTERN AND CENTRAL AFRICA
# 2649       IDA         2023   WESTERN AND CENTRAL AFRICA
#
#                          Country  Gross Disbursement (US$)  Repayments (US$)  \
# 730                         Peru              5.971323e+07      7.519931e+08
# 323                       Brazil              3.065687e+09      4.169492e+09
# ...
